# %%
# base imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Важная настройка для корректной настройки pipeline!
import sklearn
sklearn.set_config(transform_output="pandas")

# Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline

# for model learning
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score

# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
import category_encoders as ce

# Models
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
import lightgbm as lgb # устоявшееся соглашение импорта
from lightgbm import LGBMRegressor

# Metrics
from sklearn.metrics import mean_squared_log_error, mean_squared_error, mean_absolute_error, r2_score

# Tuning parametrs
import optuna
from sklearn.model_selection import KFold

# notebook settings
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Импорт пайплайна препроцессинга

# %%
from custom_process import MyTransformer, MissingValueReplacer

# %%
from joblib import load

preprocessing = load('preprocessing_pipeline.pkl')

# %% [markdown]
# ### 0. Загрузка датасета

# %%
data = pd.read_csv('/Users/alex_eyfler/ds_bootcamp/first-phase-projects/house_prices_kaggle_regression/original data/train.csv')
X_df = preprocessing.transform(data)
df = pd.concat([X_df, data['SalePrice']], axis=1)

X, y_log = df.drop('SalePrice', axis=1), np.log(df['SalePrice'])

X_train, X_valid, y_log_train, y_log_valid = train_test_split(
    X,
    y_log,
    test_size=0.2,
    random_state=52
)
# Out:
# /Users/alex_eyfler/ds_bootcamp/first-phase-projects/house_prices_kaggle_regression/Lambert/custom_process.py:29: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[columns_with_values] = X[columns_with_values].replace(replace_map)
# /Users/alex_eyfler/ds_bootcamp/first-phase-projects/house_prices_kaggle_regression/env/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /Users/alex_eyfler/ds_bootcamp/first-phase-projects/house_prices_kaggle_regression/Lambert/custom_process.py:39: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X.replace('Missing', 0, inplace=True)

# %% [markdown]
# ### 1. Пробуем CatBoost с базовыми настройками

# %%
cat_boost_1 = CatBoostRegressor()

cat_boost_1.fit(
    X_train,
    y_log_train
)
# Out:
# Learning rate set to 0.04196
# 0:	learn: 0.3795880	total: 61.6ms	remaining: 1m 1s
# 1:	learn: 0.3701026	total: 63ms	remaining: 31.4s
# 2:	learn: 0.3606640	total: 64.2ms	remaining: 21.3s
# 3:	learn: 0.3513891	total: 65.6ms	remaining: 16.3s
# 4:	learn: 0.3422470	total: 66.7ms	remaining: 13.3s
# 5:	learn: 0.3339571	total: 68.4ms	remaining: 11.3s
# 6:	learn: 0.3253107	total: 69.6ms	remaining: 9.88s
# 7:	learn: 0.3166813	total: 70.8ms	remaining: 8.77s
# 8:	learn: 0.3092280	total: 71.8ms	remaining: 7.91s
# 9:	learn: 0.3017018	total: 73ms	remaining: 7.22s
# 10:	learn: 0.2942890	total: 74.4ms	remaining: 6.69s
# 11:	learn: 0.2877308	total: 75.8ms	remaining: 6.24s
# 12:	learn: 0.2806799	total: 77.7ms	remaining: 5.9s
# 13:	learn: 0.2748413	total: 79.1ms	remaining: 5.57s
# 14:	learn: 0.2688649	total: 80.3ms	remaining: 5.28s
# 15:	learn: 0.2625957	total: 81.5ms	remaining: 5.01s
# 16:	learn: 0.2563005	total: 82.8ms	remaining: 4.79s
# 17:	learn: 0.2509871	total: 83.9ms	remaining: 4.58s
# 18:	learn: 0.2458817	total: 85.7ms	remaining: 4.42s
# 19:	learn: 0.2408120	total: 86.8ms	remaining: 4.25s
# 20:	learn: 0.2357735	total: 88.1ms	remaining: 4.11s
# 21:	learn: 0.2311811	total: 89.3ms	remaining: 3.97s
# 22:	learn: 0.2271088	total: 90.6ms	remaining: 3.85s
# 23:	learn: 0.2226615	total: 91.9ms	remaining: 3.73s
# 24:	learn: 0.2185102	total: 92.9ms	remaining: 3.62s
# 25:	learn: 0.2145577	total: 94.2ms	remaining: 3.53s
# 26:	learn: 0.2106415	total: 95.3ms	remaining: 3.43s
# 27:	learn: 0.2067384	total: 96.5ms	remaining: 3.35s
# 28:	learn: 0.2032587	total: 97.7ms	remaining: 3.27s
# 29:	learn: 0.1996312	total: 99.5ms	remaining: 3.22s
# 30:	learn: 0.1963315	total: 101ms	remaining: 3.15s
# 31:	learn: 0.1934876	total: 102ms	remaining: 3.09s
# 32:	learn: 0.1903509	total: 103ms	remaining: 3.02s
# 33:	learn: 0.1870615	total: 104ms	remaining: 2.96s
# 34:	learn: 0.1843656	total: 106ms	remaining: 2.91s
# 35:	learn: 0.1819548	total: 107ms	remaining: 2.87s
# 36:	learn: 0.1797214	total: 109ms	remaining: 2.83s
# 37:	learn: 0.1770588	total: 110ms	remaining: 2.79s
# 38:	learn: 0.1749647	total: 112ms	remaining: 2.75s
# 39:	learn: 0.1728564	total: 113ms	remaining: 2.71s
# 40:	learn: 0.1704750	total: 114ms	remaining: 2.67s
# 41:	learn: 0.1682976	total: 115ms	remaining: 2.63s
# 42:	learn: 0.1662802	total: 117ms	remaining: 2.6s
# 43:	learn: 0.1643495	total: 118ms	remaining: 2.56s
# 44:	learn: 0.1623858	total: 119ms	remaining: 2.52s
# 45:	learn: 0.1605768	total: 120ms	remaining: 2.5s
# 46:	learn: 0.1584470	total: 122ms	remaining: 2.47s
# 47:	learn: 0.1565883	total: 123ms	remaining: 2.44s
# 48:	learn: 0.1550156	total: 124ms	remaining: 2.41s
# 49:	learn: 0.1532953	total: 126ms	remaining: 2.4s
# 50:	learn: 0.1518262	total: 128ms	remaining: 2.37s
# 51:	learn: 0.1502696	total: 129ms	remaining: 2.35s
# 52:	learn: 0.1487468	total: 130ms	remaining: 2.32s
# 53:	learn: 0.1474486	total: 131ms	remaining: 2.3s
# 54:	learn: 0.1461620	total: 133ms	remaining: 2.28s
# 55:	learn: 0.1448811	total: 134ms	remaining: 2.26s
# 56:	learn: 0.1436010	total: 135ms	remaining: 2.24s
# 57:	learn: 0.1422508	total: 137ms	remaining: 2.22s
# 58:	learn: 0.1410624	total: 138ms	remaining: 2.2s
# 59:	learn: 0.1398165	total: 139ms	remaining: 2.18s
# 60:	learn: 0.1387350	total: 141ms	remaining: 2.16s
# 61:	learn: 0.1376267	total: 142ms	remaining: 2.15s
# 62:	learn: 0.1365109	total: 143ms	remaining: 2.13s
# 63:	learn: 0.1354759	total: 144ms	remaining: 2.11s
# 64:	learn: 0.1346377	total: 146ms	remaining: 2.09s
# 65:	learn: 0.1338498	total: 147ms	remaining: 2.08s
# 66:	learn: 0.1329984	total: 148ms	remaining: 2.07s
# 67:	learn: 0.1320824	total: 150ms	remaining: 2.06s
# 68:	learn: 0.1312679	total: 152ms	remaining: 2.04s
# 69:	learn: 0.1301989	total: 153ms	remaining: 2.03s
# 70:	learn: 0.1291580	total: 154ms	remaining: 2.01s
# 71:	learn: 0.1284614	total: 155ms	remaining: 2s
# 72:	learn: 0.1278198	total: 157ms	remaining: 1.99s
# 73:	learn: 0.1271283	total: 158ms	remaining: 1.97s
# 74:	learn: 0.1262836	total: 159ms	remaining: 1.97s
# 75:	learn: 0.1256357	total: 161ms	remaining: 1.95s
# 76:	learn: 0.1249848	total: 162ms	remaining: 1.94s
# 77:	learn: 0.1243364	total: 163ms	remaining: 1.93s
# 78:	learn: 0.1236773	total: 165ms	remaining: 1.92s
# 79:	learn: 0.1230591	total: 167ms	remaining: 1.92s
# 80:	learn: 0.1223824	total: 168ms	remaining: 1.91s
# 81:	learn: 0.1216909	total: 169ms	remaining: 1.89s
# 82:	learn: 0.1211608	total: 171ms	remaining: 1.88s
# 83:	learn: 0.1205425	total: 172ms	remaining: 1.87s
# 84:	learn: 0.1198488	total: 173ms	remaining: 1.86s
# 85:	learn: 0.1192390	total: 175ms	remaining: 1.85s
# 86:	learn: 0.1187115	total: 176ms	remaining: 1.84s
# 87:	learn: 0.1181914	total: 177ms	remaining: 1.83s
# 88:	learn: 0.1175779	total: 178ms	remaining: 1.82s
# 89:	learn: 0.1171073	total: 181ms	remaining: 1.83s
# 90:	learn: 0.1166916	total: 183ms	remaining: 1.83s
# 91:	learn: 0.1164032	total: 184ms	remaining: 1.82s
# 92:	learn: 0.1160414	total: 185ms	remaining: 1.81s
# 93:	learn: 0.1154511	total: 187ms	remaining: 1.8s
# 94:	learn: 0.1150946	total: 188ms	remaining: 1.79s
# 95:	learn: 0.1146563	total: 190ms	remaining: 1.79s
# 96:	learn: 0.1142832	total: 191ms	remaining: 1.78s
# 97:	learn: 0.1138246	total: 192ms	remaining: 1.77s
# 98:	learn: 0.1134081	total: 193ms	remaining: 1.76s
# 99:	learn: 0.1130462	total: 195ms	remaining: 1.75s
# 100:	learn: 0.1126495	total: 197ms	remaining: 1.75s
# 101:	learn: 0.1122147	total: 198ms	remaining: 1.74s
# 102:	learn: 0.1118258	total: 199ms	remaining: 1.73s
# 103:	learn: 0.1114383	total: 200ms	remaining: 1.73s
# 104:	learn: 0.1110156	total: 202ms	remaining: 1.72s
# 105:	learn: 0.1106255	total: 204ms	remaining: 1.72s
# 106:	learn: 0.1102399	total: 206ms	remaining: 1.72s
# 107:	learn: 0.1098940	total: 208ms	remaining: 1.72s
# 108:	learn: 0.1095801	total: 211ms	remaining: 1.72s
# 109:	learn: 0.1092699	total: 213ms	remaining: 1.72s
# 110:	learn: 0.1088454	total: 214ms	remaining: 1.72s
# 111:	learn: 0.1084801	total: 216ms	remaining: 1.71s
# 112:	learn: 0.1082142	total: 217ms	remaining: 1.7s
# 113:	learn: 0.1080009	total: 218ms	remaining: 1.69s
# 114:	learn: 0.1076830	total: 219ms	remaining: 1.69s
# 115:	learn: 0.1073488	total: 221ms	remaining: 1.68s
# 116:	learn: 0.1070892	total: 222ms	remaining: 1.68s
# 117:	learn: 0.1067711	total: 223ms	remaining: 1.67s
# 118:	learn: 0.1064719	total: 224ms	remaining: 1.66s
# 119:	learn: 0.1061871	total: 226ms	remaining: 1.66s
# 120:	learn: 0.1057392	total: 228ms	remaining: 1.66s
# 121:	learn: 0.1054446	total: 230ms	remaining: 1.65s
# 122:	learn: 0.1051691	total: 231ms	remaining: 1.65s
# 123:	learn: 0.1048258	total: 232ms	remaining: 1.64s
# 124:	learn: 0.1045333	total: 233ms	remaining: 1.63s
# 125:	learn: 0.1043547	total: 234ms	remaining: 1.62s
# 126:	learn: 0.1041384	total: 235ms	remaining: 1.62s
# 127:	learn: 0.1038812	total: 237ms	remaining: 1.61s
# 128:	learn: 0.1036433	total: 238ms	remaining: 1.61s
# 129:	learn: 0.1033820	total: 240ms	remaining: 1.6s
# 130:	learn: 0.1031033	total: 241ms	remaining: 1.6s
# 131:	learn: 0.1028659	total: 243ms	remaining: 1.6s
# 132:	learn: 0.1025785	total: 244ms	remaining: 1.59s
# 133:	learn: 0.1023548	total: 246ms	remaining: 1.59s
# 134:	learn: 0.1021373	total: 247ms	remaining: 1.58s
# 135:	learn: 0.1018779	total: 248ms	remaining: 1.58s
# 136:	learn: 0.1017238	total: 250ms	remaining: 1.57s
# 137:	learn: 0.1014666	total: 251ms	remaining: 1.57s
# 138:	learn: 0.1011456	total: 252ms	remaining: 1.56s
# 139:	learn: 0.1008555	total: 254ms	remaining: 1.56s
# 140:	learn: 0.1007630	total: 255ms	remaining: 1.55s
# 141:	learn: 0.1005538	total: 256ms	remaining: 1.55s
# 142:	learn: 0.1003479	total: 258ms	remaining: 1.55s
# 143:	learn: 0.1001582	total: 261ms	remaining: 1.55s
# 144:	learn: 0.0999139	total: 262ms	remaining: 1.54s
# 145:	learn: 0.0996935	total: 263ms	remaining: 1.54s
# 146:	learn: 0.0994813	total: 264ms	remaining: 1.53s
# 147:	learn: 0.0993242	total: 266ms	remaining: 1.53s
# 148:	learn: 0.0990726	total: 267ms	remaining: 1.52s
# 149:	learn: 0.0988979	total: 268ms	remaining: 1.52s
# 150:	learn: 0.0986047	total: 269ms	remaining: 1.51s
# 151:	learn: 0.0983474	total: 270ms	remaining: 1.51s
# 152:	learn: 0.0981878	total: 272ms	remaining: 1.51s
# 153:	learn: 0.0980020	total: 274ms	remaining: 1.5s
# 154:	learn: 0.0978387	total: 275ms	remaining: 1.5s
# 155:	learn: 0.0976506	total: 277ms	remaining: 1.5s
# 156:	learn: 0.0974839	total: 278ms	remaining: 1.49s
# 157:	learn: 0.0971652	total: 279ms	remaining: 1.49s
# 158:	learn: 0.0970027	total: 280ms	remaining: 1.48s
# 159:	learn: 0.0967131	total: 281ms	remaining: 1.48s
# 160:	learn: 0.0965204	total: 282ms	remaining: 1.47s
# 161:	learn: 0.0963491	total: 284ms	remaining: 1.47s
# 162:	learn: 0.0961775	total: 285ms	remaining: 1.46s
# 163:	learn: 0.0958845	total: 286ms	remaining: 1.46s
# 164:	learn: 0.0956218	total: 287ms	remaining: 1.45s
# 165:	learn: 0.0953787	total: 289ms	remaining: 1.45s
# 166:	learn: 0.0952977	total: 291ms	remaining: 1.45s
# 167:	learn: 0.0951743	total: 292ms	remaining: 1.44s
# 168:	learn: 0.0949309	total: 293ms	remaining: 1.44s
# 169:	learn: 0.0948259	total: 294ms	remaining: 1.43s
# 170:	learn: 0.0946706	total: 295ms	remaining: 1.43s
# 171:	learn: 0.0945323	total: 297ms	remaining: 1.43s
# 172:	learn: 0.0943232	total: 298ms	remaining: 1.42s
# 173:	learn: 0.0941467	total: 299ms	remaining: 1.42s
# 174:	learn: 0.0939821	total: 300ms	remaining: 1.42s
# 175:	learn: 0.0938109	total: 302ms	remaining: 1.41s
# 176:	learn: 0.0936407	total: 303ms	remaining: 1.41s
# 177:	learn: 0.0935585	total: 304ms	remaining: 1.4s
# 178:	learn: 0.0935073	total: 307ms	remaining: 1.41s
# 179:	learn: 0.0932726	total: 308ms	remaining: 1.4s
# 180:	learn: 0.0931352	total: 309ms	remaining: 1.4s
# 181:	learn: 0.0929679	total: 311ms	remaining: 1.4s
# 182:	learn: 0.0926795	total: 312ms	remaining: 1.39s
# 183:	learn: 0.0925758	total: 313ms	remaining: 1.39s
# 184:	learn: 0.0924191	total: 314ms	remaining: 1.39s
# 185:	learn: 0.0922815	total: 315ms	remaining: 1.38s
# 186:	learn: 0.0921979	total: 317ms	remaining: 1.38s
# 187:	learn: 0.0921061	total: 318ms	remaining: 1.38s
# 188:	learn: 0.0919431	total: 320ms	remaining: 1.37s
# 189:	learn: 0.0918135	total: 321ms	remaining: 1.37s
# 190:	learn: 0.0916980	total: 322ms	remaining: 1.36s
# 191:	learn: 0.0914988	total: 323ms	remaining: 1.36s
# 192:	learn: 0.0912811	total: 324ms	remaining: 1.36s
# 193:	learn: 0.0911757	total: 326ms	remaining: 1.35s
# 194:	learn: 0.0910683	total: 327ms	remaining: 1.35s
# 195:	learn: 0.0909495	total: 328ms	remaining: 1.35s
# 196:	learn: 0.0908169	total: 329ms	remaining: 1.34s
# 197:	learn: 0.0906797	total: 331ms	remaining: 1.34s
# 198:	learn: 0.0904078	total: 332ms	remaining: 1.33s
# 199:	learn: 0.0903079	total: 333ms	remaining: 1.33s
# 200:	learn: 0.0901412	total: 334ms	remaining: 1.33s
# 201:	learn: 0.0899819	total: 335ms	remaining: 1.32s
# 202:	learn: 0.0897405	total: 337ms	remaining: 1.32s
# 203:	learn: 0.0895641	total: 338ms	remaining: 1.32s
# 204:	learn: 0.0894448	total: 340ms	remaining: 1.32s
# 205:	learn: 0.0893104	total: 341ms	remaining: 1.31s
# 206:	learn: 0.0890553	total: 342ms	remaining: 1.31s
# 207:	learn: 0.0888252	total: 343ms	remaining: 1.31s
# 208:	learn: 0.0887269	total: 345ms	remaining: 1.31s
# 209:	learn: 0.0886600	total: 346ms	remaining: 1.3s
# 210:	learn: 0.0885433	total: 348ms	remaining: 1.3s
# 211:	learn: 0.0883228	total: 349ms	remaining: 1.3s
# 212:	learn: 0.0881305	total: 351ms	remaining: 1.3s
# 213:	learn: 0.0879287	total: 352ms	remaining: 1.29s
# 214:	learn: 0.0878046	total: 353ms	remaining: 1.29s
# 215:	learn: 0.0877530	total: 355ms	remaining: 1.29s
# 216:	learn: 0.0875974	total: 356ms	remaining: 1.28s
# 217:	learn: 0.0874284	total: 357ms	remaining: 1.28s
# 218:	learn: 0.0872555	total: 358ms	remaining: 1.28s
# 219:	learn: 0.0871693	total: 359ms	remaining: 1.27s
# 220:	learn: 0.0870374	total: 360ms	remaining: 1.27s
# 221:	learn: 0.0868373	total: 362ms	remaining: 1.27s
# 222:	learn: 0.0867673	total: 363ms	remaining: 1.26s
# 223:	learn: 0.0865592	total: 364ms	remaining: 1.26s
# 224:	learn: 0.0863576	total: 366ms	remaining: 1.26s
# 225:	learn: 0.0862807	total: 367ms	remaining: 1.26s
# 226:	learn: 0.0862226	total: 369ms	remaining: 1.25s
# 227:	learn: 0.0860758	total: 370ms	remaining: 1.25s
# 228:	learn: 0.0859409	total: 371ms	remaining: 1.25s
# 229:	learn: 0.0858228	total: 372ms	remaining: 1.25s
# 230:	learn: 0.0856566	total: 374ms	remaining: 1.25s
# 231:	learn: 0.0856002	total: 376ms	remaining: 1.24s
# 232:	learn: 0.0855041	total: 377ms	remaining: 1.24s
# 233:	learn: 0.0852566	total: 379ms	remaining: 1.24s
# 234:	learn: 0.0852035	total: 380ms	remaining: 1.24s
# 235:	learn: 0.0849990	total: 386ms	remaining: 1.25s
# 236:	learn: 0.0849483	total: 389ms	remaining: 1.25s
# 237:	learn: 0.0848167	total: 390ms	remaining: 1.25s
# 238:	learn: 0.0846137	total: 391ms	remaining: 1.25s
# 239:	learn: 0.0843954	total: 392ms	remaining: 1.24s
# 240:	learn: 0.0842197	total: 394ms	remaining: 1.24s
# 241:	learn: 0.0841801	total: 397ms	remaining: 1.24s
# 242:	learn: 0.0841279	total: 398ms	remaining: 1.24s
# 243:	learn: 0.0839619	total: 399ms	remaining: 1.24s
# 244:	learn: 0.0837657	total: 400ms	remaining: 1.23s
# 245:	learn: 0.0835540	total: 402ms	remaining: 1.23s
# 246:	learn: 0.0834919	total: 403ms	remaining: 1.23s
# 247:	learn: 0.0833410	total: 405ms	remaining: 1.23s
# 248:	learn: 0.0831520	total: 406ms	remaining: 1.22s
# 249:	learn: 0.0830056	total: 407ms	remaining: 1.22s
# 250:	learn: 0.0828176	total: 408ms	remaining: 1.22s
# 251:	learn: 0.0826368	total: 410ms	remaining: 1.22s
# 252:	learn: 0.0824204	total: 411ms	remaining: 1.21s
# 253:	learn: 0.0822498	total: 412ms	remaining: 1.21s
# 254:	learn: 0.0821040	total: 413ms	remaining: 1.21s
# 255:	learn: 0.0820698	total: 415ms	remaining: 1.2s
# 256:	learn: 0.0819092	total: 416ms	remaining: 1.2s
# 257:	learn: 0.0818554	total: 417ms	remaining: 1.2s
# 258:	learn: 0.0817256	total: 418ms	remaining: 1.2s
# 259:	learn: 0.0816807	total: 420ms	remaining: 1.19s
# 260:	learn: 0.0815054	total: 421ms	remaining: 1.19s
# 261:	learn: 0.0813069	total: 423ms	remaining: 1.19s
# 262:	learn: 0.0811767	total: 424ms	remaining: 1.19s
# 263:	learn: 0.0810318	total: 426ms	remaining: 1.19s
# 264:	learn: 0.0809312	total: 428ms	remaining: 1.19s
# 265:	learn: 0.0808078	total: 429ms	remaining: 1.18s
# 266:	learn: 0.0806028	total: 431ms	remaining: 1.18s
# 267:	learn: 0.0805606	total: 432ms	remaining: 1.18s
# 268:	learn: 0.0803829	total: 435ms	remaining: 1.18s
# 269:	learn: 0.0801781	total: 436ms	remaining: 1.18s
# 270:	learn: 0.0800615	total: 438ms	remaining: 1.18s
# 271:	learn: 0.0800317	total: 440ms	remaining: 1.18s
# 272:	learn: 0.0799893	total: 441ms	remaining: 1.17s
# 273:	learn: 0.0799514	total: 442ms	remaining: 1.17s
# 274:	learn: 0.0798258	total: 445ms	remaining: 1.17s
# 275:	learn: 0.0797417	total: 446ms	remaining: 1.17s
# 276:	learn: 0.0795379	total: 448ms	remaining: 1.17s
# 277:	learn: 0.0794942	total: 450ms	remaining: 1.17s
# 278:	learn: 0.0793117	total: 451ms	remaining: 1.17s
# 279:	learn: 0.0791607	total: 452ms	remaining: 1.16s
# 280:	learn: 0.0790060	total: 454ms	remaining: 1.16s
# 281:	learn: 0.0789132	total: 455ms	remaining: 1.16s
# 282:	learn: 0.0787842	total: 457ms	remaining: 1.16s
# 283:	learn: 0.0787567	total: 458ms	remaining: 1.16s
# 284:	learn: 0.0786765	total: 460ms	remaining: 1.15s
# 285:	learn: 0.0785736	total: 462ms	remaining: 1.15s
# 286:	learn: 0.0784739	total: 463ms	remaining: 1.15s
# 287:	learn: 0.0783090	total: 465ms	remaining: 1.15s
# 288:	learn: 0.0782020	total: 467ms	remaining: 1.15s
# 289:	learn: 0.0780454	total: 468ms	remaining: 1.15s
# 290:	learn: 0.0779642	total: 470ms	remaining: 1.14s
# 291:	learn: 0.0778990	total: 471ms	remaining: 1.14s
# 292:	learn: 0.0778748	total: 473ms	remaining: 1.14s
# 293:	learn: 0.0778510	total: 474ms	remaining: 1.14s
# 294:	learn: 0.0776656	total: 476ms	remaining: 1.14s
# 295:	learn: 0.0775428	total: 477ms	remaining: 1.13s
# 296:	learn: 0.0773950	total: 478ms	remaining: 1.13s
# 297:	learn: 0.0773057	total: 480ms	remaining: 1.13s
# 298:	learn: 0.0770961	total: 482ms	remaining: 1.13s
# 299:	learn: 0.0769791	total: 483ms	remaining: 1.13s
# 300:	learn: 0.0769613	total: 485ms	remaining: 1.13s
# 301:	learn: 0.0768356	total: 486ms	remaining: 1.12s
# 302:	learn: 0.0766330	total: 488ms	remaining: 1.12s
# 303:	learn: 0.0765028	total: 490ms	remaining: 1.12s
# 304:	learn: 0.0764702	total: 492ms	remaining: 1.12s
# 305:	learn: 0.0763366	total: 493ms	remaining: 1.12s
# 306:	learn: 0.0762692	total: 495ms	remaining: 1.12s
# 307:	learn: 0.0761699	total: 497ms	remaining: 1.11s
# 308:	learn: 0.0760508	total: 499ms	remaining: 1.11s
# 309:	learn: 0.0759868	total: 501ms	remaining: 1.11s
# 310:	learn: 0.0759394	total: 502ms	remaining: 1.11s
# 311:	learn: 0.0759013	total: 504ms	remaining: 1.11s
# 312:	learn: 0.0757918	total: 506ms	remaining: 1.11s
# 313:	learn: 0.0756994	total: 507ms	remaining: 1.11s
# 314:	learn: 0.0756828	total: 509ms	remaining: 1.11s
# 315:	learn: 0.0754599	total: 511ms	remaining: 1.1s
# 316:	learn: 0.0753222	total: 513ms	remaining: 1.1s
# 317:	learn: 0.0751922	total: 515ms	remaining: 1.1s
# 318:	learn: 0.0750592	total: 517ms	remaining: 1.1s
# 319:	learn: 0.0749488	total: 519ms	remaining: 1.1s
# 320:	learn: 0.0749349	total: 521ms	remaining: 1.1s
# 321:	learn: 0.0747860	total: 522ms	remaining: 1.1s
# 322:	learn: 0.0746472	total: 524ms	remaining: 1.1s
# 323:	learn: 0.0745354	total: 526ms	remaining: 1.1s
# 324:	learn: 0.0743329	total: 528ms	remaining: 1.1s
# 325:	learn: 0.0741948	total: 529ms	remaining: 1.09s
# 326:	learn: 0.0741794	total: 531ms	remaining: 1.09s
# 327:	learn: 0.0741645	total: 533ms	remaining: 1.09s
# 328:	learn: 0.0740349	total: 535ms	remaining: 1.09s
# 329:	learn: 0.0740206	total: 537ms	remaining: 1.09s
# 330:	learn: 0.0739789	total: 538ms	remaining: 1.09s
# 331:	learn: 0.0738593	total: 541ms	remaining: 1.09s
# 332:	learn: 0.0737607	total: 542ms	remaining: 1.08s
# 333:	learn: 0.0735619	total: 544ms	remaining: 1.08s
# 334:	learn: 0.0734367	total: 545ms	remaining: 1.08s
# 335:	learn: 0.0732727	total: 548ms	remaining: 1.08s
# 336:	learn: 0.0731684	total: 550ms	remaining: 1.08s
# 337:	learn: 0.0730493	total: 551ms	remaining: 1.08s
# 338:	learn: 0.0728505	total: 553ms	remaining: 1.08s
# 339:	learn: 0.0727483	total: 555ms	remaining: 1.08s
# 340:	learn: 0.0726376	total: 556ms	remaining: 1.07s
# 341:	learn: 0.0724602	total: 558ms	remaining: 1.07s
# 342:	learn: 0.0723161	total: 560ms	remaining: 1.07s
# 343:	learn: 0.0721325	total: 562ms	remaining: 1.07s
# 344:	learn: 0.0719706	total: 564ms	remaining: 1.07s
# 345:	learn: 0.0719572	total: 566ms	remaining: 1.07s
# 346:	learn: 0.0718538	total: 569ms	remaining: 1.07s
# 347:	learn: 0.0717107	total: 571ms	remaining: 1.07s
# 348:	learn: 0.0716416	total: 572ms	remaining: 1.07s
# 349:	learn: 0.0715290	total: 574ms	remaining: 1.06s
# 350:	learn: 0.0714089	total: 576ms	remaining: 1.06s
# 351:	learn: 0.0713930	total: 577ms	remaining: 1.06s
# 352:	learn: 0.0712703	total: 578ms	remaining: 1.06s
# 353:	learn: 0.0712578	total: 579ms	remaining: 1.06s
# 354:	learn: 0.0711660	total: 581ms	remaining: 1.05s
# 355:	learn: 0.0710578	total: 583ms	remaining: 1.05s
# 356:	learn: 0.0709394	total: 585ms	remaining: 1.05s
# 357:	learn: 0.0708186	total: 587ms	remaining: 1.05s
# 358:	learn: 0.0707308	total: 589ms	remaining: 1.05s
# 359:	learn: 0.0705552	total: 590ms	remaining: 1.05s
# 360:	learn: 0.0705402	total: 592ms	remaining: 1.05s
# 361:	learn: 0.0705153	total: 593ms	remaining: 1.04s
# 362:	learn: 0.0703489	total: 595ms	remaining: 1.04s
# 363:	learn: 0.0702891	total: 596ms	remaining: 1.04s
# 364:	learn: 0.0702101	total: 598ms	remaining: 1.04s
# 365:	learn: 0.0701950	total: 600ms	remaining: 1.04s
# 366:	learn: 0.0701805	total: 601ms	remaining: 1.04s
# 367:	learn: 0.0700485	total: 602ms	remaining: 1.03s
# 368:	learn: 0.0700363	total: 604ms	remaining: 1.03s
# 369:	learn: 0.0699890	total: 606ms	remaining: 1.03s
# 370:	learn: 0.0698744	total: 607ms	remaining: 1.03s
# 371:	learn: 0.0697611	total: 609ms	remaining: 1.03s
# 372:	learn: 0.0696842	total: 610ms	remaining: 1.02s
# 373:	learn: 0.0696021	total: 611ms	remaining: 1.02s
# 374:	learn: 0.0694845	total: 612ms	remaining: 1.02s
# 375:	learn: 0.0694146	total: 614ms	remaining: 1.02s
# 376:	learn: 0.0692798	total: 615ms	remaining: 1.02s
# 377:	learn: 0.0691250	total: 617ms	remaining: 1.01s
# 378:	learn: 0.0690062	total: 618ms	remaining: 1.01s
# 379:	learn: 0.0688792	total: 620ms	remaining: 1.01s
# 380:	learn: 0.0687544	total: 622ms	remaining: 1.01s
# 381:	learn: 0.0685727	total: 623ms	remaining: 1.01s
# 382:	learn: 0.0684616	total: 624ms	remaining: 1s
# 383:	learn: 0.0683461	total: 626ms	remaining: 1s
# 384:	learn: 0.0682641	total: 627ms	remaining: 1s
# 385:	learn: 0.0681015	total: 628ms	remaining: 999ms
# 386:	learn: 0.0680880	total: 629ms	remaining: 997ms
# 387:	learn: 0.0680658	total: 630ms	remaining: 994ms
# 388:	learn: 0.0679808	total: 632ms	remaining: 992ms
# 389:	learn: 0.0678531	total: 633ms	remaining: 990ms
# 390:	learn: 0.0677506	total: 634ms	remaining: 987ms
# 391:	learn: 0.0676275	total: 635ms	remaining: 985ms
# 392:	learn: 0.0674728	total: 637ms	remaining: 983ms
# 393:	learn: 0.0673782	total: 638ms	remaining: 981ms
# 394:	learn: 0.0672381	total: 639ms	remaining: 979ms
# 395:	learn: 0.0671324	total: 640ms	remaining: 976ms
# 396:	learn: 0.0670682	total: 641ms	remaining: 974ms
# 397:	learn: 0.0670562	total: 643ms	remaining: 972ms
# 398:	learn: 0.0669318	total: 644ms	remaining: 970ms
# 399:	learn: 0.0667836	total: 645ms	remaining: 967ms
# 400:	learn: 0.0666864	total: 647ms	remaining: 966ms
# 401:	learn: 0.0666489	total: 648ms	remaining: 963ms
# 402:	learn: 0.0665413	total: 649ms	remaining: 961ms
# 403:	learn: 0.0663875	total: 650ms	remaining: 959ms
# 404:	learn: 0.0663139	total: 652ms	remaining: 958ms
# 405:	learn: 0.0661982	total: 653ms	remaining: 956ms
# 406:	learn: 0.0660942	total: 655ms	remaining: 954ms
# 407:	learn: 0.0660130	total: 656ms	remaining: 952ms
# 408:	learn: 0.0659257	total: 657ms	remaining: 949ms
# 409:	learn: 0.0658881	total: 658ms	remaining: 947ms
# 410:	learn: 0.0657375	total: 660ms	remaining: 945ms
# 411:	learn: 0.0656555	total: 661ms	remaining: 943ms
# 412:	learn: 0.0655828	total: 662ms	remaining: 941ms
# 413:	learn: 0.0654814	total: 663ms	remaining: 939ms
# 414:	learn: 0.0654318	total: 665ms	remaining: 937ms
# 415:	learn: 0.0653169	total: 666ms	remaining: 935ms
# 416:	learn: 0.0652093	total: 667ms	remaining: 933ms
# 417:	learn: 0.0651329	total: 669ms	remaining: 931ms
# 418:	learn: 0.0650198	total: 670ms	remaining: 929ms
# 419:	learn: 0.0649307	total: 671ms	remaining: 927ms
# 420:	learn: 0.0648237	total: 672ms	remaining: 925ms
# 421:	learn: 0.0647121	total: 674ms	remaining: 923ms
# 422:	learn: 0.0647008	total: 675ms	remaining: 920ms
# 423:	learn: 0.0645601	total: 676ms	remaining: 919ms
# 424:	learn: 0.0644782	total: 678ms	remaining: 918ms
# 425:	learn: 0.0643590	total: 680ms	remaining: 916ms
# 426:	learn: 0.0643201	total: 681ms	remaining: 913ms
# 427:	learn: 0.0642030	total: 682ms	remaining: 912ms
# 428:	learn: 0.0641488	total: 684ms	remaining: 910ms
# 429:	learn: 0.0640264	total: 686ms	remaining: 909ms
# 430:	learn: 0.0640141	total: 687ms	remaining: 908ms
# 431:	learn: 0.0640033	total: 689ms	remaining: 905ms
# 432:	learn: 0.0639836	total: 690ms	remaining: 903ms
# 433:	learn: 0.0639403	total: 691ms	remaining: 901ms
# 434:	learn: 0.0638752	total: 692ms	remaining: 899ms
# 435:	learn: 0.0637891	total: 693ms	remaining: 897ms
# 436:	learn: 0.0636888	total: 695ms	remaining: 895ms
# 437:	learn: 0.0636779	total: 696ms	remaining: 893ms
# 438:	learn: 0.0636169	total: 697ms	remaining: 891ms
# 439:	learn: 0.0635337	total: 698ms	remaining: 889ms
# 440:	learn: 0.0634241	total: 700ms	remaining: 887ms
# 441:	learn: 0.0633164	total: 702ms	remaining: 886ms
# 442:	learn: 0.0631876	total: 704ms	remaining: 885ms
# 443:	learn: 0.0630676	total: 705ms	remaining: 883ms
# 444:	learn: 0.0629810	total: 706ms	remaining: 881ms
# 445:	learn: 0.0628789	total: 708ms	remaining: 880ms
# 446:	learn: 0.0627938	total: 710ms	remaining: 878ms
# 447:	learn: 0.0627843	total: 711ms	remaining: 876ms
# 448:	learn: 0.0627634	total: 712ms	remaining: 874ms
# 449:	learn: 0.0627255	total: 714ms	remaining: 873ms
# 450:	learn: 0.0626130	total: 715ms	remaining: 871ms
# 451:	learn: 0.0625021	total: 717ms	remaining: 869ms
# 452:	learn: 0.0624347	total: 718ms	remaining: 867ms
# 453:	learn: 0.0623674	total: 719ms	remaining: 864ms
# 454:	learn: 0.0622757	total: 720ms	remaining: 862ms
# 455:	learn: 0.0621451	total: 721ms	remaining: 861ms
# 456:	learn: 0.0620996	total: 723ms	remaining: 859ms
# 457:	learn: 0.0620400	total: 724ms	remaining: 857ms
# 458:	learn: 0.0619695	total: 725ms	remaining: 855ms
# 459:	learn: 0.0618583	total: 726ms	remaining: 853ms
# 460:	learn: 0.0617573	total: 728ms	remaining: 851ms
# 461:	learn: 0.0616506	total: 729ms	remaining: 849ms
# 462:	learn: 0.0615935	total: 731ms	remaining: 848ms
# 463:	learn: 0.0615031	total: 732ms	remaining: 846ms
# 464:	learn: 0.0614375	total: 733ms	remaining: 844ms
# 465:	learn: 0.0614022	total: 735ms	remaining: 842ms
# 466:	learn: 0.0612974	total: 736ms	remaining: 840ms
# 467:	learn: 0.0612630	total: 737ms	remaining: 838ms
# 468:	learn: 0.0611973	total: 739ms	remaining: 837ms
# 469:	learn: 0.0610544	total: 740ms	remaining: 835ms
# 470:	learn: 0.0609737	total: 742ms	remaining: 833ms
# 471:	learn: 0.0608912	total: 743ms	remaining: 831ms
# 472:	learn: 0.0608099	total: 744ms	remaining: 829ms
# 473:	learn: 0.0607459	total: 745ms	remaining: 827ms
# 474:	learn: 0.0607286	total: 747ms	remaining: 826ms
# 475:	learn: 0.0607195	total: 748ms	remaining: 824ms
# 476:	learn: 0.0606408	total: 750ms	remaining: 822ms
# 477:	learn: 0.0605822	total: 751ms	remaining: 820ms
# 478:	learn: 0.0605229	total: 753ms	remaining: 819ms
# 479:	learn: 0.0604275	total: 755ms	remaining: 817ms
# 480:	learn: 0.0603265	total: 756ms	remaining: 816ms
# 481:	learn: 0.0601700	total: 758ms	remaining: 814ms
# 482:	learn: 0.0600939	total: 759ms	remaining: 812ms
# 483:	learn: 0.0600697	total: 761ms	remaining: 811ms
# 484:	learn: 0.0599680	total: 763ms	remaining: 810ms
# 485:	learn: 0.0599315	total: 764ms	remaining: 808ms
# 486:	learn: 0.0598301	total: 765ms	remaining: 806ms
# 487:	learn: 0.0597912	total: 767ms	remaining: 804ms
# 488:	learn: 0.0596895	total: 768ms	remaining: 802ms
# 489:	learn: 0.0596473	total: 769ms	remaining: 801ms
# 490:	learn: 0.0596404	total: 771ms	remaining: 799ms
# 491:	learn: 0.0595508	total: 773ms	remaining: 798ms
# 492:	learn: 0.0594978	total: 774ms	remaining: 796ms
# 493:	learn: 0.0594054	total: 775ms	remaining: 794ms
# 494:	learn: 0.0593401	total: 776ms	remaining: 792ms
# 495:	learn: 0.0592866	total: 778ms	remaining: 791ms
# 496:	learn: 0.0592459	total: 779ms	remaining: 789ms
# 497:	learn: 0.0592391	total: 780ms	remaining: 787ms
# 498:	learn: 0.0591487	total: 782ms	remaining: 785ms
# 499:	learn: 0.0591420	total: 783ms	remaining: 783ms
# 500:	learn: 0.0590811	total: 784ms	remaining: 781ms
# 501:	learn: 0.0589638	total: 785ms	remaining: 779ms
# 502:	learn: 0.0588688	total: 787ms	remaining: 777ms
# 503:	learn: 0.0587490	total: 788ms	remaining: 776ms
# 504:	learn: 0.0586752	total: 790ms	remaining: 774ms
# 505:	learn: 0.0585649	total: 791ms	remaining: 772ms
# 506:	learn: 0.0585081	total: 792ms	remaining: 770ms
# 507:	learn: 0.0583761	total: 794ms	remaining: 769ms
# 508:	learn: 0.0583612	total: 795ms	remaining: 767ms
# 509:	learn: 0.0583145	total: 797ms	remaining: 765ms
# 510:	learn: 0.0582278	total: 799ms	remaining: 764ms
# 511:	learn: 0.0582202	total: 800ms	remaining: 762ms
# 512:	learn: 0.0581131	total: 801ms	remaining: 760ms
# 513:	learn: 0.0580317	total: 802ms	remaining: 759ms
# 514:	learn: 0.0579772	total: 803ms	remaining: 757ms
# 515:	learn: 0.0578647	total: 805ms	remaining: 755ms
# 516:	learn: 0.0577806	total: 806ms	remaining: 753ms
# 517:	learn: 0.0577279	total: 807ms	remaining: 751ms
# 518:	learn: 0.0576328	total: 809ms	remaining: 749ms
# 519:	learn: 0.0576250	total: 810ms	remaining: 748ms
# 520:	learn: 0.0576056	total: 812ms	remaining: 747ms
# 521:	learn: 0.0575457	total: 814ms	remaining: 745ms
# 522:	learn: 0.0574415	total: 815ms	remaining: 744ms
# 523:	learn: 0.0573674	total: 816ms	remaining: 742ms
# 524:	learn: 0.0572838	total: 818ms	remaining: 740ms
# 525:	learn: 0.0572785	total: 819ms	remaining: 738ms
# 526:	learn: 0.0572370	total: 821ms	remaining: 737ms
# 527:	learn: 0.0572313	total: 822ms	remaining: 735ms
# 528:	learn: 0.0571362	total: 824ms	remaining: 734ms
# 529:	learn: 0.0570326	total: 826ms	remaining: 732ms
# 530:	learn: 0.0570032	total: 827ms	remaining: 731ms
# 531:	learn: 0.0569219	total: 829ms	remaining: 729ms
# 532:	learn: 0.0568435	total: 830ms	remaining: 727ms
# 533:	learn: 0.0567701	total: 831ms	remaining: 725ms
# 534:	learn: 0.0566497	total: 833ms	remaining: 724ms
# 535:	learn: 0.0565785	total: 834ms	remaining: 722ms
# 536:	learn: 0.0565053	total: 835ms	remaining: 720ms
# 537:	learn: 0.0563571	total: 837ms	remaining: 719ms
# 538:	learn: 0.0562780	total: 838ms	remaining: 717ms
# 539:	learn: 0.0561663	total: 840ms	remaining: 715ms
# 540:	learn: 0.0560502	total: 841ms	remaining: 714ms
# 541:	learn: 0.0559741	total: 843ms	remaining: 712ms
# 542:	learn: 0.0559228	total: 845ms	remaining: 711ms
# 543:	learn: 0.0558276	total: 846ms	remaining: 710ms
# 544:	learn: 0.0557762	total: 848ms	remaining: 708ms
# 545:	learn: 0.0557561	total: 849ms	remaining: 706ms
# 546:	learn: 0.0556635	total: 851ms	remaining: 704ms
# 547:	learn: 0.0555626	total: 852ms	remaining: 703ms
# 548:	learn: 0.0554972	total: 853ms	remaining: 701ms
# 549:	learn: 0.0553573	total: 855ms	remaining: 699ms
# 550:	learn: 0.0552918	total: 856ms	remaining: 697ms
# 551:	learn: 0.0552343	total: 858ms	remaining: 696ms
# 552:	learn: 0.0552128	total: 860ms	remaining: 695ms
# 553:	learn: 0.0551565	total: 862ms	remaining: 694ms
# 554:	learn: 0.0550577	total: 864ms	remaining: 693ms
# 555:	learn: 0.0549972	total: 865ms	remaining: 691ms
# 556:	learn: 0.0549276	total: 867ms	remaining: 689ms
# 557:	learn: 0.0548686	total: 868ms	remaining: 688ms
# 558:	learn: 0.0548629	total: 870ms	remaining: 686ms
# 559:	learn: 0.0548578	total: 872ms	remaining: 685ms
# 560:	learn: 0.0548052	total: 873ms	remaining: 684ms
# 561:	learn: 0.0546952	total: 875ms	remaining: 682ms
# 562:	learn: 0.0546036	total: 877ms	remaining: 681ms
# 563:	learn: 0.0545001	total: 879ms	remaining: 679ms
# 564:	learn: 0.0544629	total: 881ms	remaining: 678ms
# 565:	learn: 0.0544373	total: 882ms	remaining: 676ms
# 566:	learn: 0.0542958	total: 884ms	remaining: 675ms
# 567:	learn: 0.0541947	total: 885ms	remaining: 673ms
# 568:	learn: 0.0541204	total: 887ms	remaining: 672ms
# 569:	learn: 0.0541133	total: 889ms	remaining: 670ms
# 570:	learn: 0.0541073	total: 891ms	remaining: 669ms
# 571:	learn: 0.0540353	total: 892ms	remaining: 668ms
# 572:	learn: 0.0539132	total: 894ms	remaining: 666ms
# 573:	learn: 0.0538186	total: 895ms	remaining: 664ms
# 574:	learn: 0.0537891	total: 897ms	remaining: 663ms
# 575:	learn: 0.0536888	total: 899ms	remaining: 662ms
# 576:	learn: 0.0536838	total: 901ms	remaining: 660ms
# 577:	learn: 0.0536480	total: 902ms	remaining: 658ms
# 578:	learn: 0.0535599	total: 903ms	remaining: 657ms
# 579:	learn: 0.0534838	total: 905ms	remaining: 655ms
# 580:	learn: 0.0534553	total: 907ms	remaining: 654ms
# 581:	learn: 0.0534505	total: 909ms	remaining: 653ms
# 582:	learn: 0.0534237	total: 910ms	remaining: 651ms
# 583:	learn: 0.0534199	total: 911ms	remaining: 649ms
# 584:	learn: 0.0533423	total: 913ms	remaining: 648ms
# 585:	learn: 0.0532639	total: 915ms	remaining: 646ms
# 586:	learn: 0.0531853	total: 916ms	remaining: 644ms
# 587:	learn: 0.0531090	total: 917ms	remaining: 642ms
# 588:	learn: 0.0531003	total: 918ms	remaining: 641ms
# 589:	learn: 0.0530007	total: 920ms	remaining: 639ms
# 590:	learn: 0.0529813	total: 921ms	remaining: 638ms
# 591:	learn: 0.0529751	total: 924ms	remaining: 637ms
# 592:	learn: 0.0529242	total: 925ms	remaining: 635ms
# 593:	learn: 0.0528744	total: 926ms	remaining: 633ms
# 594:	learn: 0.0528306	total: 928ms	remaining: 631ms
# 595:	learn: 0.0527707	total: 929ms	remaining: 630ms
# 596:	learn: 0.0526818	total: 930ms	remaining: 628ms
# 597:	learn: 0.0525693	total: 931ms	remaining: 626ms
# 598:	learn: 0.0524686	total: 933ms	remaining: 624ms
# 599:	learn: 0.0524119	total: 934ms	remaining: 623ms
# 600:	learn: 0.0523570	total: 935ms	remaining: 621ms
# 601:	learn: 0.0522811	total: 937ms	remaining: 619ms
# 602:	learn: 0.0522222	total: 939ms	remaining: 618ms
# 603:	learn: 0.0521390	total: 941ms	remaining: 617ms
# 604:	learn: 0.0520559	total: 943ms	remaining: 616ms
# 605:	learn: 0.0520082	total: 944ms	remaining: 614ms
# 606:	learn: 0.0519241	total: 945ms	remaining: 612ms
# 607:	learn: 0.0518075	total: 947ms	remaining: 610ms
# 608:	learn: 0.0517756	total: 948ms	remaining: 609ms
# 609:	learn: 0.0517644	total: 949ms	remaining: 607ms
# 610:	learn: 0.0516497	total: 951ms	remaining: 605ms
# 611:	learn: 0.0515370	total: 953ms	remaining: 605ms
# 612:	learn: 0.0515004	total: 955ms	remaining: 603ms
# 613:	learn: 0.0514312	total: 956ms	remaining: 601ms
# 614:	learn: 0.0513174	total: 958ms	remaining: 600ms
# 615:	learn: 0.0513120	total: 959ms	remaining: 598ms
# 616:	learn: 0.0513008	total: 960ms	remaining: 596ms
# 617:	learn: 0.0512142	total: 961ms	remaining: 594ms
# 618:	learn: 0.0511463	total: 963ms	remaining: 593ms
# 619:	learn: 0.0510711	total: 964ms	remaining: 591ms
# 620:	learn: 0.0510341	total: 966ms	remaining: 589ms
# 621:	learn: 0.0509808	total: 967ms	remaining: 588ms
# 622:	learn: 0.0509187	total: 969ms	remaining: 586ms
# 623:	learn: 0.0507747	total: 971ms	remaining: 585ms
# 624:	learn: 0.0507151	total: 972ms	remaining: 583ms
# 625:	learn: 0.0506635	total: 974ms	remaining: 582ms
# 626:	learn: 0.0506000	total: 975ms	remaining: 580ms
# 627:	learn: 0.0505727	total: 977ms	remaining: 579ms
# 628:	learn: 0.0505579	total: 979ms	remaining: 578ms
# 629:	learn: 0.0504781	total: 981ms	remaining: 576ms
# 630:	learn: 0.0504285	total: 982ms	remaining: 574ms
# 631:	learn: 0.0504239	total: 983ms	remaining: 572ms
# 632:	learn: 0.0503534	total: 985ms	remaining: 571ms
# 633:	learn: 0.0503049	total: 986ms	remaining: 569ms
# 634:	learn: 0.0502772	total: 988ms	remaining: 568ms
# 635:	learn: 0.0502567	total: 989ms	remaining: 566ms
# 636:	learn: 0.0502250	total: 990ms	remaining: 564ms
# 637:	learn: 0.0501864	total: 991ms	remaining: 563ms
# 638:	learn: 0.0500987	total: 993ms	remaining: 561ms
# 639:	learn: 0.0500321	total: 994ms	remaining: 559ms
# 640:	learn: 0.0499488	total: 996ms	remaining: 558ms
# 641:	learn: 0.0498615	total: 997ms	remaining: 556ms
# 642:	learn: 0.0497923	total: 998ms	remaining: 554ms
# 643:	learn: 0.0497391	total: 1s	remaining: 553ms
# 644:	learn: 0.0497199	total: 1s	remaining: 551ms
# 645:	learn: 0.0496666	total: 1s	remaining: 550ms
# 646:	learn: 0.0495948	total: 1s	remaining: 548ms
# 647:	learn: 0.0495906	total: 1s	remaining: 546ms
# 648:	learn: 0.0495380	total: 1.01s	remaining: 545ms
# 649:	learn: 0.0494689	total: 1.01s	remaining: 543ms
# 650:	learn: 0.0494486	total: 1.01s	remaining: 541ms
# 651:	learn: 0.0494036	total: 1.01s	remaining: 540ms
# 652:	learn: 0.0494002	total: 1.01s	remaining: 538ms
# 653:	learn: 0.0493351	total: 1.01s	remaining: 536ms
# 654:	learn: 0.0493125	total: 1.01s	remaining: 535ms
# 655:	learn: 0.0492214	total: 1.02s	remaining: 533ms
# 656:	learn: 0.0491945	total: 1.02s	remaining: 532ms
# 657:	learn: 0.0490817	total: 1.02s	remaining: 530ms
# 658:	learn: 0.0489758	total: 1.02s	remaining: 529ms
# 659:	learn: 0.0488946	total: 1.02s	remaining: 528ms
# 660:	learn: 0.0488095	total: 1.02s	remaining: 526ms
# 661:	learn: 0.0487337	total: 1.03s	remaining: 524ms
# 662:	learn: 0.0487303	total: 1.03s	remaining: 523ms
# 663:	learn: 0.0486655	total: 1.03s	remaining: 521ms
# 664:	learn: 0.0486309	total: 1.03s	remaining: 520ms
# 665:	learn: 0.0486029	total: 1.03s	remaining: 518ms
# 666:	learn: 0.0485013	total: 1.03s	remaining: 517ms
# 667:	learn: 0.0484027	total: 1.04s	remaining: 515ms
# 668:	learn: 0.0483720	total: 1.04s	remaining: 514ms
# 669:	learn: 0.0482879	total: 1.04s	remaining: 512ms
# 670:	learn: 0.0481896	total: 1.04s	remaining: 511ms
# 671:	learn: 0.0481416	total: 1.04s	remaining: 509ms
# 672:	learn: 0.0481382	total: 1.04s	remaining: 507ms
# 673:	learn: 0.0480707	total: 1.04s	remaining: 506ms
# 674:	learn: 0.0479596	total: 1.05s	remaining: 504ms
# 675:	learn: 0.0479561	total: 1.05s	remaining: 502ms
# 676:	learn: 0.0479090	total: 1.05s	remaining: 501ms
# 677:	learn: 0.0478082	total: 1.05s	remaining: 499ms
# 678:	learn: 0.0477558	total: 1.05s	remaining: 497ms
# 679:	learn: 0.0477397	total: 1.05s	remaining: 496ms
# 680:	learn: 0.0476604	total: 1.05s	remaining: 494ms
# 681:	learn: 0.0476324	total: 1.06s	remaining: 493ms
# 682:	learn: 0.0475771	total: 1.06s	remaining: 491ms
# 683:	learn: 0.0475089	total: 1.06s	remaining: 489ms
# 684:	learn: 0.0474852	total: 1.06s	remaining: 488ms
# 685:	learn: 0.0474437	total: 1.06s	remaining: 486ms
# 686:	learn: 0.0474005	total: 1.06s	remaining: 485ms
# 687:	learn: 0.0473103	total: 1.06s	remaining: 483ms
# 688:	learn: 0.0473000	total: 1.07s	remaining: 481ms
# 689:	learn: 0.0472016	total: 1.07s	remaining: 480ms
# 690:	learn: 0.0471370	total: 1.07s	remaining: 478ms
# 691:	learn: 0.0471239	total: 1.07s	remaining: 476ms
# 692:	learn: 0.0470680	total: 1.07s	remaining: 475ms
# 693:	learn: 0.0470044	total: 1.07s	remaining: 473ms
# 694:	learn: 0.0469243	total: 1.07s	remaining: 471ms
# 695:	learn: 0.0468299	total: 1.07s	remaining: 470ms
# 696:	learn: 0.0467725	total: 1.08s	remaining: 469ms
# 697:	learn: 0.0467575	total: 1.08s	remaining: 467ms
# 698:	learn: 0.0466817	total: 1.08s	remaining: 465ms
# 699:	learn: 0.0466081	total: 1.08s	remaining: 464ms
# 700:	learn: 0.0465967	total: 1.08s	remaining: 462ms
# 701:	learn: 0.0465433	total: 1.08s	remaining: 461ms
# 702:	learn: 0.0464759	total: 1.09s	remaining: 459ms
# 703:	learn: 0.0464028	total: 1.09s	remaining: 457ms
# 704:	learn: 0.0463094	total: 1.09s	remaining: 456ms
# 705:	learn: 0.0462847	total: 1.09s	remaining: 454ms
# 706:	learn: 0.0462541	total: 1.09s	remaining: 452ms
# 707:	learn: 0.0462300	total: 1.09s	remaining: 451ms
# 708:	learn: 0.0461450	total: 1.09s	remaining: 450ms
# 709:	learn: 0.0460968	total: 1.1s	remaining: 448ms
# 710:	learn: 0.0460391	total: 1.1s	remaining: 446ms
# 711:	learn: 0.0459885	total: 1.1s	remaining: 445ms
# 712:	learn: 0.0459661	total: 1.1s	remaining: 443ms
# 713:	learn: 0.0459114	total: 1.1s	remaining: 441ms
# 714:	learn: 0.0458232	total: 1.1s	remaining: 440ms
# 715:	learn: 0.0457427	total: 1.1s	remaining: 438ms
# 716:	learn: 0.0456552	total: 1.1s	remaining: 436ms
# 717:	learn: 0.0456304	total: 1.11s	remaining: 435ms
# 718:	learn: 0.0456178	total: 1.11s	remaining: 433ms
# 719:	learn: 0.0455933	total: 1.11s	remaining: 432ms
# 720:	learn: 0.0455724	total: 1.11s	remaining: 430ms
# 721:	learn: 0.0455694	total: 1.11s	remaining: 428ms
# 722:	learn: 0.0455145	total: 1.11s	remaining: 427ms
# 723:	learn: 0.0454783	total: 1.11s	remaining: 425ms
# 724:	learn: 0.0454200	total: 1.12s	remaining: 424ms
# 725:	learn: 0.0454152	total: 1.12s	remaining: 422ms
# 726:	learn: 0.0453449	total: 1.12s	remaining: 420ms
# 727:	learn: 0.0452745	total: 1.12s	remaining: 419ms
# 728:	learn: 0.0452074	total: 1.12s	remaining: 417ms
# 729:	learn: 0.0451448	total: 1.12s	remaining: 415ms
# 730:	learn: 0.0450535	total: 1.12s	remaining: 414ms
# 731:	learn: 0.0450034	total: 1.13s	remaining: 412ms
# 732:	learn: 0.0449369	total: 1.13s	remaining: 411ms
# 733:	learn: 0.0448526	total: 1.13s	remaining: 409ms
# 734:	learn: 0.0447738	total: 1.13s	remaining: 407ms
# 735:	learn: 0.0447104	total: 1.13s	remaining: 406ms
# 736:	learn: 0.0446606	total: 1.13s	remaining: 404ms
# 737:	learn: 0.0446211	total: 1.13s	remaining: 403ms
# 738:	learn: 0.0445467	total: 1.14s	remaining: 401ms
# 739:	learn: 0.0445431	total: 1.14s	remaining: 400ms
# 740:	learn: 0.0445176	total: 1.14s	remaining: 398ms
# 741:	learn: 0.0444724	total: 1.14s	remaining: 396ms
# 742:	learn: 0.0444432	total: 1.14s	remaining: 395ms
# 743:	learn: 0.0444211	total: 1.14s	remaining: 393ms
# 744:	learn: 0.0443988	total: 1.15s	remaining: 392ms
# 745:	learn: 0.0443232	total: 1.15s	remaining: 391ms
# 746:	learn: 0.0442070	total: 1.15s	remaining: 389ms
# 747:	learn: 0.0441579	total: 1.15s	remaining: 387ms
# 748:	learn: 0.0440885	total: 1.15s	remaining: 386ms
# 749:	learn: 0.0440325	total: 1.15s	remaining: 384ms
# 750:	learn: 0.0440095	total: 1.15s	remaining: 383ms
# 751:	learn: 0.0439524	total: 1.16s	remaining: 381ms
# 752:	learn: 0.0439338	total: 1.16s	remaining: 380ms
# 753:	learn: 0.0438679	total: 1.16s	remaining: 379ms
# 754:	learn: 0.0437770	total: 1.16s	remaining: 377ms
# 755:	learn: 0.0437736	total: 1.16s	remaining: 376ms
# 756:	learn: 0.0437235	total: 1.16s	remaining: 374ms
# 757:	learn: 0.0437160	total: 1.17s	remaining: 372ms
# 758:	learn: 0.0436350	total: 1.17s	remaining: 371ms
# 759:	learn: 0.0435615	total: 1.17s	remaining: 369ms
# 760:	learn: 0.0435390	total: 1.17s	remaining: 368ms
# 761:	learn: 0.0435145	total: 1.17s	remaining: 366ms
# 762:	learn: 0.0434883	total: 1.17s	remaining: 364ms
# 763:	learn: 0.0434317	total: 1.18s	remaining: 363ms
# 764:	learn: 0.0434163	total: 1.18s	remaining: 362ms
# 765:	learn: 0.0433761	total: 1.18s	remaining: 360ms
# 766:	learn: 0.0432775	total: 1.18s	remaining: 359ms
# 767:	learn: 0.0432184	total: 1.18s	remaining: 357ms
# 768:	learn: 0.0432159	total: 1.18s	remaining: 355ms
# 769:	learn: 0.0432095	total: 1.18s	remaining: 354ms
# 770:	learn: 0.0431529	total: 1.19s	remaining: 352ms
# 771:	learn: 0.0430749	total: 1.19s	remaining: 351ms
# 772:	learn: 0.0430155	total: 1.19s	remaining: 349ms
# 773:	learn: 0.0429709	total: 1.19s	remaining: 347ms
# 774:	learn: 0.0429684	total: 1.19s	remaining: 346ms
# 775:	learn: 0.0429490	total: 1.19s	remaining: 345ms
# 776:	learn: 0.0428663	total: 1.2s	remaining: 343ms
# 777:	learn: 0.0428116	total: 1.2s	remaining: 342ms
# 778:	learn: 0.0427516	total: 1.2s	remaining: 340ms
# 779:	learn: 0.0426759	total: 1.2s	remaining: 339ms
# 780:	learn: 0.0426681	total: 1.2s	remaining: 337ms
# 781:	learn: 0.0426460	total: 1.2s	remaining: 335ms
# 782:	learn: 0.0426202	total: 1.2s	remaining: 334ms
# 783:	learn: 0.0426032	total: 1.21s	remaining: 332ms
# 784:	learn: 0.0425670	total: 1.21s	remaining: 331ms
# 785:	learn: 0.0425350	total: 1.21s	remaining: 329ms
# 786:	learn: 0.0425212	total: 1.21s	remaining: 328ms
# 787:	learn: 0.0424719	total: 1.21s	remaining: 326ms
# 788:	learn: 0.0424516	total: 1.21s	remaining: 324ms
# 789:	learn: 0.0423983	total: 1.21s	remaining: 323ms
# 790:	learn: 0.0423352	total: 1.22s	remaining: 321ms
# 791:	learn: 0.0422543	total: 1.22s	remaining: 320ms
# 792:	learn: 0.0421937	total: 1.22s	remaining: 318ms
# 793:	learn: 0.0421458	total: 1.22s	remaining: 317ms
# 794:	learn: 0.0421110	total: 1.22s	remaining: 315ms
# 795:	learn: 0.0420332	total: 1.22s	remaining: 314ms
# 796:	learn: 0.0419886	total: 1.23s	remaining: 312ms
# 797:	learn: 0.0419460	total: 1.23s	remaining: 310ms
# 798:	learn: 0.0418971	total: 1.23s	remaining: 309ms
# 799:	learn: 0.0418946	total: 1.23s	remaining: 307ms
# 800:	learn: 0.0418570	total: 1.23s	remaining: 306ms
# 801:	learn: 0.0418187	total: 1.23s	remaining: 304ms
# 802:	learn: 0.0417614	total: 1.23s	remaining: 303ms
# 803:	learn: 0.0417249	total: 1.23s	remaining: 301ms
# 804:	learn: 0.0416740	total: 1.24s	remaining: 299ms
# 805:	learn: 0.0416625	total: 1.24s	remaining: 298ms
# 806:	learn: 0.0415764	total: 1.24s	remaining: 296ms
# 807:	learn: 0.0415308	total: 1.24s	remaining: 295ms
# 808:	learn: 0.0415083	total: 1.24s	remaining: 293ms
# 809:	learn: 0.0414673	total: 1.24s	remaining: 292ms
# 810:	learn: 0.0414550	total: 1.25s	remaining: 290ms
# 811:	learn: 0.0413888	total: 1.25s	remaining: 289ms
# 812:	learn: 0.0413382	total: 1.25s	remaining: 287ms
# 813:	learn: 0.0412732	total: 1.25s	remaining: 286ms
# 814:	learn: 0.0412710	total: 1.25s	remaining: 284ms
# 815:	learn: 0.0412298	total: 1.25s	remaining: 283ms
# 816:	learn: 0.0411518	total: 1.25s	remaining: 281ms
# 817:	learn: 0.0411244	total: 1.26s	remaining: 280ms
# 818:	learn: 0.0411174	total: 1.26s	remaining: 278ms
# 819:	learn: 0.0410526	total: 1.26s	remaining: 276ms
# 820:	learn: 0.0410321	total: 1.26s	remaining: 275ms
# 821:	learn: 0.0409836	total: 1.26s	remaining: 273ms
# 822:	learn: 0.0409374	total: 1.26s	remaining: 272ms
# 823:	learn: 0.0408827	total: 1.26s	remaining: 270ms
# 824:	learn: 0.0408166	total: 1.27s	remaining: 269ms
# 825:	learn: 0.0407879	total: 1.27s	remaining: 267ms
# 826:	learn: 0.0406959	total: 1.27s	remaining: 266ms
# 827:	learn: 0.0406738	total: 1.27s	remaining: 264ms
# 828:	learn: 0.0406172	total: 1.27s	remaining: 263ms
# 829:	learn: 0.0406031	total: 1.27s	remaining: 261ms
# 830:	learn: 0.0405693	total: 1.27s	remaining: 259ms
# 831:	learn: 0.0405044	total: 1.28s	remaining: 258ms
# 832:	learn: 0.0404318	total: 1.28s	remaining: 256ms
# 833:	learn: 0.0403806	total: 1.28s	remaining: 255ms
# 834:	learn: 0.0403000	total: 1.28s	remaining: 253ms
# 835:	learn: 0.0402317	total: 1.28s	remaining: 252ms
# 836:	learn: 0.0401959	total: 1.28s	remaining: 250ms
# 837:	learn: 0.0401412	total: 1.29s	remaining: 249ms
# 838:	learn: 0.0401307	total: 1.29s	remaining: 247ms
# 839:	learn: 0.0400894	total: 1.29s	remaining: 246ms
# 840:	learn: 0.0400606	total: 1.29s	remaining: 244ms
# 841:	learn: 0.0400171	total: 1.29s	remaining: 243ms
# 842:	learn: 0.0399745	total: 1.29s	remaining: 241ms
# 843:	learn: 0.0399351	total: 1.3s	remaining: 240ms
# 844:	learn: 0.0398407	total: 1.3s	remaining: 238ms
# 845:	learn: 0.0398020	total: 1.3s	remaining: 236ms
# 846:	learn: 0.0397229	total: 1.3s	remaining: 235ms
# 847:	learn: 0.0396603	total: 1.3s	remaining: 233ms
# 848:	learn: 0.0396435	total: 1.3s	remaining: 232ms
# 849:	learn: 0.0396265	total: 1.3s	remaining: 230ms
# 850:	learn: 0.0395889	total: 1.31s	remaining: 229ms
# 851:	learn: 0.0395330	total: 1.31s	remaining: 227ms
# 852:	learn: 0.0395310	total: 1.31s	remaining: 226ms
# 853:	learn: 0.0394825	total: 1.31s	remaining: 224ms
# 854:	learn: 0.0394365	total: 1.31s	remaining: 223ms
# 855:	learn: 0.0394064	total: 1.31s	remaining: 221ms
# 856:	learn: 0.0393689	total: 1.31s	remaining: 219ms
# 857:	learn: 0.0393058	total: 1.31s	remaining: 218ms
# 858:	learn: 0.0392907	total: 1.32s	remaining: 216ms
# 859:	learn: 0.0392122	total: 1.32s	remaining: 215ms
# 860:	learn: 0.0391795	total: 1.32s	remaining: 213ms
# 861:	learn: 0.0391544	total: 1.32s	remaining: 212ms
# 862:	learn: 0.0390948	total: 1.32s	remaining: 210ms
# 863:	learn: 0.0390482	total: 1.32s	remaining: 209ms
# 864:	learn: 0.0389773	total: 1.33s	remaining: 207ms
# 865:	learn: 0.0389750	total: 1.33s	remaining: 205ms
# 866:	learn: 0.0389061	total: 1.33s	remaining: 204ms
# 867:	learn: 0.0388750	total: 1.33s	remaining: 202ms
# 868:	learn: 0.0388557	total: 1.33s	remaining: 201ms
# 869:	learn: 0.0387987	total: 1.33s	remaining: 199ms
# 870:	learn: 0.0387689	total: 1.34s	remaining: 198ms
# 871:	learn: 0.0387083	total: 1.34s	remaining: 196ms
# 872:	learn: 0.0386488	total: 1.34s	remaining: 195ms
# 873:	learn: 0.0386045	total: 1.34s	remaining: 193ms
# 874:	learn: 0.0385350	total: 1.34s	remaining: 192ms
# 875:	learn: 0.0385198	total: 1.34s	remaining: 190ms
# 876:	learn: 0.0385158	total: 1.34s	remaining: 189ms
# 877:	learn: 0.0384567	total: 1.35s	remaining: 187ms
# 878:	learn: 0.0383883	total: 1.35s	remaining: 186ms
# 879:	learn: 0.0383861	total: 1.35s	remaining: 184ms
# 880:	learn: 0.0383349	total: 1.35s	remaining: 183ms
# 881:	learn: 0.0383121	total: 1.35s	remaining: 181ms
# 882:	learn: 0.0382796	total: 1.35s	remaining: 179ms
# 883:	learn: 0.0382364	total: 1.36s	remaining: 178ms
# 884:	learn: 0.0381691	total: 1.36s	remaining: 176ms
# 885:	learn: 0.0381241	total: 1.36s	remaining: 175ms
# 886:	learn: 0.0381090	total: 1.36s	remaining: 173ms
# 887:	learn: 0.0380397	total: 1.36s	remaining: 172ms
# 888:	learn: 0.0380375	total: 1.36s	remaining: 170ms
# 889:	learn: 0.0379733	total: 1.36s	remaining: 169ms
# 890:	learn: 0.0379579	total: 1.37s	remaining: 167ms
# 891:	learn: 0.0379160	total: 1.37s	remaining: 166ms
# 892:	learn: 0.0378672	total: 1.37s	remaining: 164ms
# 893:	learn: 0.0378112	total: 1.37s	remaining: 162ms
# 894:	learn: 0.0377402	total: 1.37s	remaining: 161ms
# 895:	learn: 0.0377140	total: 1.37s	remaining: 159ms
# 896:	learn: 0.0376803	total: 1.37s	remaining: 158ms
# 897:	learn: 0.0376093	total: 1.38s	remaining: 156ms
# 898:	learn: 0.0375587	total: 1.38s	remaining: 155ms
# 899:	learn: 0.0375425	total: 1.38s	remaining: 153ms
# 900:	learn: 0.0374835	total: 1.38s	remaining: 152ms
# 901:	learn: 0.0374364	total: 1.38s	remaining: 150ms
# 902:	learn: 0.0373714	total: 1.38s	remaining: 149ms
# 903:	learn: 0.0373692	total: 1.38s	remaining: 147ms
# 904:	learn: 0.0373141	total: 1.39s	remaining: 145ms
# 905:	learn: 0.0372513	total: 1.39s	remaining: 144ms
# 906:	learn: 0.0372015	total: 1.39s	remaining: 142ms
# 907:	learn: 0.0371687	total: 1.39s	remaining: 141ms
# 908:	learn: 0.0371666	total: 1.39s	remaining: 139ms
# 909:	learn: 0.0371648	total: 1.39s	remaining: 138ms
# 910:	learn: 0.0371384	total: 1.39s	remaining: 136ms
# 911:	learn: 0.0370989	total: 1.39s	remaining: 135ms
# 912:	learn: 0.0370629	total: 1.4s	remaining: 133ms
# 913:	learn: 0.0370280	total: 1.4s	remaining: 131ms
# 914:	learn: 0.0369575	total: 1.4s	remaining: 130ms
# 915:	learn: 0.0369125	total: 1.4s	remaining: 128ms
# 916:	learn: 0.0368733	total: 1.4s	remaining: 127ms
# 917:	learn: 0.0368433	total: 1.4s	remaining: 125ms
# 918:	learn: 0.0368015	total: 1.4s	remaining: 124ms
# 919:	learn: 0.0367447	total: 1.4s	remaining: 122ms
# 920:	learn: 0.0367146	total: 1.41s	remaining: 121ms
# 921:	learn: 0.0366897	total: 1.41s	remaining: 119ms
# 922:	learn: 0.0366478	total: 1.41s	remaining: 118ms
# 923:	learn: 0.0366440	total: 1.41s	remaining: 116ms
# 924:	learn: 0.0365817	total: 1.41s	remaining: 114ms
# 925:	learn: 0.0365486	total: 1.41s	remaining: 113ms
# 926:	learn: 0.0365019	total: 1.41s	remaining: 111ms
# 927:	learn: 0.0364455	total: 1.42s	remaining: 110ms
# 928:	learn: 0.0364177	total: 1.42s	remaining: 108ms
# 929:	learn: 0.0363992	total: 1.42s	remaining: 107ms
# 930:	learn: 0.0363533	total: 1.42s	remaining: 105ms
# 931:	learn: 0.0363478	total: 1.42s	remaining: 104ms
# 932:	learn: 0.0363126	total: 1.42s	remaining: 102ms
# 933:	learn: 0.0362536	total: 1.42s	remaining: 101ms
# 934:	learn: 0.0362174	total: 1.42s	remaining: 99ms
# 935:	learn: 0.0361662	total: 1.43s	remaining: 97.5ms
# 936:	learn: 0.0361608	total: 1.43s	remaining: 95.9ms
# 937:	learn: 0.0361311	total: 1.43s	remaining: 94.4ms
# 938:	learn: 0.0360803	total: 1.43s	remaining: 92.9ms
# 939:	learn: 0.0360238	total: 1.43s	remaining: 91.4ms
# 940:	learn: 0.0359971	total: 1.43s	remaining: 89.8ms
# 941:	learn: 0.0359600	total: 1.43s	remaining: 88.3ms
# 942:	learn: 0.0359309	total: 1.43s	remaining: 86.7ms
# 943:	learn: 0.0358884	total: 1.44s	remaining: 85.2ms
# 944:	learn: 0.0358405	total: 1.44s	remaining: 83.6ms
# 945:	learn: 0.0358049	total: 1.44s	remaining: 82.1ms
# 946:	learn: 0.0357610	total: 1.44s	remaining: 80.6ms
# 947:	learn: 0.0357106	total: 1.44s	remaining: 79.1ms
# 948:	learn: 0.0356790	total: 1.44s	remaining: 77.5ms
# 949:	learn: 0.0356516	total: 1.44s	remaining: 76ms
# 950:	learn: 0.0356069	total: 1.45s	remaining: 74.5ms
# 951:	learn: 0.0355728	total: 1.45s	remaining: 73ms
# 952:	learn: 0.0355029	total: 1.45s	remaining: 71.4ms
# 953:	learn: 0.0354607	total: 1.45s	remaining: 69.9ms
# 954:	learn: 0.0354484	total: 1.45s	remaining: 68.4ms
# 955:	learn: 0.0353997	total: 1.45s	remaining: 66.8ms
# 956:	learn: 0.0353643	total: 1.45s	remaining: 65.3ms
# 957:	learn: 0.0353414	total: 1.46s	remaining: 63.8ms
# 958:	learn: 0.0353067	total: 1.46s	remaining: 62.3ms
# 959:	learn: 0.0352484	total: 1.46s	remaining: 60.8ms
# 960:	learn: 0.0352174	total: 1.46s	remaining: 59.2ms
# 961:	learn: 0.0351548	total: 1.46s	remaining: 57.7ms
# 962:	learn: 0.0351307	total: 1.46s	remaining: 56.2ms
# 963:	learn: 0.0350880	total: 1.46s	remaining: 54.7ms
# 964:	learn: 0.0350353	total: 1.47s	remaining: 53.2ms
# 965:	learn: 0.0350142	total: 1.47s	remaining: 51.7ms
# 966:	learn: 0.0349732	total: 1.47s	remaining: 50.1ms
# 967:	learn: 0.0349453	total: 1.47s	remaining: 48.6ms
# 968:	learn: 0.0349112	total: 1.47s	remaining: 47.1ms
# 969:	learn: 0.0348648	total: 1.47s	remaining: 45.6ms
# 970:	learn: 0.0348169	total: 1.48s	remaining: 44.1ms
# 971:	learn: 0.0347645	total: 1.48s	remaining: 42.6ms
# 972:	learn: 0.0347501	total: 1.48s	remaining: 41ms
# 973:	learn: 0.0347181	total: 1.48s	remaining: 39.5ms
# 974:	learn: 0.0346743	total: 1.48s	remaining: 38ms
# 975:	learn: 0.0346201	total: 1.48s	remaining: 36.5ms
# 976:	learn: 0.0345868	total: 1.48s	remaining: 35ms
# 977:	learn: 0.0345308	total: 1.49s	remaining: 33.4ms
# 978:	learn: 0.0344918	total: 1.49s	remaining: 31.9ms
# 979:	learn: 0.0344786	total: 1.49s	remaining: 30.4ms
# 980:	learn: 0.0344682	total: 1.49s	remaining: 28.9ms
# 981:	learn: 0.0344341	total: 1.49s	remaining: 27.4ms
# 982:	learn: 0.0344180	total: 1.49s	remaining: 25.8ms
# 983:	learn: 0.0344164	total: 1.5s	remaining: 24.3ms
# 984:	learn: 0.0343697	total: 1.5s	remaining: 22.8ms
# 985:	learn: 0.0343331	total: 1.5s	remaining: 21.3ms
# 986:	learn: 0.0342968	total: 1.5s	remaining: 19.8ms
# 987:	learn: 0.0342533	total: 1.5s	remaining: 18.2ms
# 988:	learn: 0.0342406	total: 1.5s	remaining: 16.7ms
# 989:	learn: 0.0341902	total: 1.51s	remaining: 15.2ms
# 990:	learn: 0.0341440	total: 1.51s	remaining: 13.7ms
# 991:	learn: 0.0340914	total: 1.51s	remaining: 12.2ms
# 992:	learn: 0.0340459	total: 1.51s	remaining: 10.7ms
# 993:	learn: 0.0340036	total: 1.51s	remaining: 9.14ms
# 994:	learn: 0.0339664	total: 1.51s	remaining: 7.62ms
# 995:	learn: 0.0339291	total: 1.52s	remaining: 6.09ms
# 996:	learn: 0.0338795	total: 1.52s	remaining: 4.57ms
# 997:	learn: 0.0338693	total: 1.52s	remaining: 3.04ms
# 998:	learn: 0.0338106	total: 1.52s	remaining: 1.52ms
# 999:	learn: 0.0337740	total: 1.52s	remaining: 0us

# %% [markdown]
# #### 1.1 Получение предсказаний и обработка метрик

# %%
# Предсказания на логарифмических данных
y_log_train_pred = cat_boost_1.predict(X_train)
y_log_valid_pred = cat_boost_1.predict(X_valid)

# Перевод предсказанных значений в обычную шкалу для дальнейшего анализа
y_train_pred = np.exp(y_log_train_pred)
y_valid_pred = np.exp(y_log_valid_pred)

# И для оригинальных значений
y_train = np.exp(y_log_train)
y_valid = np.exp(y_log_valid)


# Проверяем, что в целевых значениях и предсказаниях нет отрицательных значений
if (y_train < 0).any() or (y_valid < 0).any() or (y_train_pred < 0).any() or (y_valid_pred < 0).any():
    print("RMSLE не может быть применена, так как имеются отрицательные значения в y или в предсказаниях.")
else:
    # Вычисляем MSLE и RMSLE
    train_msle = mean_squared_log_error(y_train, y_train_pred)
    valid_msle = mean_squared_log_error(y_valid, y_valid_pred)

    print('Train MSLE:', train_msle)
    print('Validation MSLE:', valid_msle)
    print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

    print('Train RMSLE:', np.sqrt(train_msle))
    print('Validation RMSLE:', np.sqrt(valid_msle))
    print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

# Вычисляем другие метрики для более полной оценки модели

# Среднеквадратичная ошибка (MSE) и корень из MSE (RMSE)
train_mse = mean_squared_error(y_train, y_train_pred)
valid_mse = mean_squared_error(y_valid, y_valid_pred)

print('Train MSE:', train_mse)
print('Validation MSE:', valid_mse)
print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

print('Train RMSE:', np.sqrt(train_mse))
print('Validation RMSE:', np.sqrt(valid_mse))
print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

# Средняя абсолютная ошибка (MAE)
train_mae = mean_absolute_error(y_train, y_train_pred)
valid_mae = mean_absolute_error(y_valid, y_valid_pred)

print('Train MAE:', train_mae)
print('Validation MAE:', valid_mae)
print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

# Коэффициент детерминации (R²)
train_r2 = r2_score(y_train, y_train_pred)
valid_r2 = r2_score(y_valid, y_valid_pred)

print('Train R^2:', train_r2)
print('Validation R^2:', valid_r2)
# Out:
# Train MSLE: 0.0011406710710768903
# Validation MSLE: 0.016886190005431623
#
# ==============================
#
# Train RMSLE: 0.0337738222752014
# Validation RMSLE: 0.1299468737809095
#
# ==============================
#
# Train MSE: 40223732.22554607
# Validation MSE: 716859264.9293038
#
# ==============================
#
# Train RMSE: 6342.218241715281
# Validation RMSE: 26774.227625261272
#
# ==============================
#
# Train MAE: 4597.290519498844
# Validation MAE: 15062.138643641978
#
# ==============================
#
# Train R^2: 0.9931753197459061
# Validation R^2: 0.9095432936357463

# %% [markdown]
# ### 4. Тюнинг параметров для моделей

# %% [markdown]
# ### 4.1 CatBoost тюнинг

# %%
def objective(trial):
    param = {
        'iterations': trial.suggest_int('iterations', 500, 2000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'depth': trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1),
        'random_strength': trial.suggest_float('random_strength', 0, 10),
        'grow_policy': trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Depthwise', 'Lossguide']),
    }
    kf = KFold(n_splits=5, shuffle=True, random_state=52)
    rmsle_scores = []
    
    for train_index, valid_index in kf.split(X):
        X_train_cv, X_valid_cv = X.iloc[train_index], X.iloc[valid_index]
        y_train_cv, y_valid_cv = y.iloc[train_index], y.iloc[valid_index]
        
        model = CatBoostRegressor(**param)
        model.fit(X_train_cv, y_train_cv, eval_set=(X_valid_cv, y_valid_cv), verbose=False)
        
        y_pred = model.predict(X_valid_cv)
        y_pred = np.maximum(y_pred, 0)  # Убеждаемся, что прогнозы неотрицательны
        
        rmsle = np.sqrt(mean_squared_log_error(y_valid_cv, y_pred))
        rmsle_scores.append(rmsle)
    
    return np.mean(rmsle_scores)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

print('Наилучшие параметры:')
for key, value in study.best_params.items():
    print(f'{key}: {value}')

print(f'Наилучшее значение RMSLE: {study.best_value}')

# %% [markdown]
# ### 5. Проверка моделей с оптимизированными параметрами

# %% [markdown]
# ### 5.1 CatBoost оптимизированная

# %%
# Наилучшие параметры: МОИ ПЕРВЫЕ
# iterations: 1842
# learning_rate: 0.148683039214686
# depth: 4
# l2_leaf_reg: 8.976684403702432
# bagging_temperature: 0.6928364121029715
# random_strength: 3.0234103345423176
# grow_policy: SymmetricTree
# Наилучшее значение RMSLE: 0.138473644119397

# Наилучшие параметры: МАРИНА ПРЕПРОЦЕССИНГ
# iterations: 900
# learning_rate: 0.03811379337443099
# depth: 4
# l2_leaf_reg: 5.401132284019045
# bagging_temperature: 0.7921960733675621
# random_strength: 7.0013473823336065
# grow_policy: Lossguide
# Наилучшее значение RMSLE: 0.1407241390521044

# Наилучшие параметры: ЛАМБЕРТ ПРЕПРОЦЕССИНГ
# iterations: 1241
# learning_rate: 0.06071716565899703
# depth: 4
# l2_leaf_reg: 7.76892727416148
# bagging_temperature: 0.961745094190735
# random_strength: 4.9804828019633165
# grow_policy: Lossguide
# Наилучшее значение RMSLE: 0.12333375686301161

# %%
cat_boost_2 = CatBoostRegressor(
    iterations=1241,
    learning_rate=0.06071716565899703,
    depth=4,
    l2_leaf_reg=7.76892727416148,
    bagging_temperature=0.961745094190735,
    random_strength=4.9804828019633165,
    grow_policy='Lossguide'
)

cat_boost_2.fit(
    X_train,
    y_log_train
)

# %%
# Предсказания на логарифмических данных
y_log_train_pred = cat_boost_2.predict(X_train)
y_log_valid_pred = cat_boost_2.predict(X_valid)

# Перевод предсказанных значений в обычную шкалу для дальнейшего анализа
y_train_pred = np.exp(y_log_train_pred)
y_valid_pred = np.exp(y_log_valid_pred)

# И для оригинальных значений
y_train = np.exp(y_log_train)
y_valid = np.exp(y_log_valid)


# Проверяем, что в целевых значениях и предсказаниях нет отрицательных значений
if (y_train < 0).any() or (y_valid < 0).any() or (y_train_pred < 0).any() or (y_valid_pred < 0).any():
    print("RMSLE не может быть применена, так как имеются отрицательные значения в y или в предсказаниях.")
else:
    # Вычисляем MSLE и RMSLE
    train_msle = mean_squared_log_error(y_train, y_train_pred)
    valid_msle = mean_squared_log_error(y_valid, y_valid_pred)

    print('Train MSLE:', train_msle)
    print('Validation MSLE:', valid_msle)
    print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

    print('Train RMSLE:', np.sqrt(train_msle))
    print('Validation RMSLE:', np.sqrt(valid_msle))
    print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

# Вычисляем другие метрики для более полной оценки модели

# Среднеквадратичная ошибка (MSE) и корень из MSE (RMSE)
train_mse = mean_squared_error(y_train, y_train_pred)
valid_mse = mean_squared_error(y_valid, y_valid_pred)

print('Train MSE:', train_mse)
print('Validation MSE:', valid_mse)
print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

print('Train RMSE:', np.sqrt(train_mse))
print('Validation RMSE:', np.sqrt(valid_mse))
print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

# Средняя абсолютная ошибка (MAE)
train_mae = mean_absolute_error(y_train, y_train_pred)
valid_mae = mean_absolute_error(y_valid, y_valid_pred)

print('Train MAE:', train_mae)
print('Validation MAE:', valid_mae)
print("\n" + "="*30 + "\n")  # Разделитель для удобства чтения

# Коэффициент детерминации (R²)
train_r2 = r2_score(y_train, y_train_pred)
valid_r2 = r2_score(y_valid, y_valid_pred)

print('Train R^2:', train_r2)
print('Validation R^2:', valid_r2)

# Добавляем графическое представление метрик

# 1. Фактические значения vs Предсказанные значения (Обучающая выборка)
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_pred, alpha=0.3)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'r--')
plt.xlabel('Фактические значения')
plt.ylabel('Предсказанные значения')
plt.title('Фактические vs Предсказанные значения (Обучающая выборка)')
plt.show()

# 2. Фактические значения vs Предсказанные значения (Валидационная выборка)
plt.figure(figsize=(10, 6))
plt.scatter(y_valid, y_valid_pred, alpha=0.3, color='orange')
plt.plot([y_valid.min(), y_valid.max()], [y_valid.min(), y_valid.max()], 'r--')
plt.xlabel('Фактические значения')
plt.ylabel('Предсказанные значения')
plt.title('Фактические vs Предсказанные значения (Валидационная выборка)')
plt.show()

# 3. Ошибка предсказаний vs Предсказанные значения (Обучающая выборка)
train_residuals = y_train - y_train_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_train_pred, train_residuals, alpha=0.3)
plt.hlines(y=0, xmin=y_train_pred.min(), xmax=y_train_pred.max(), colors='r')
plt.xlabel('Предсказанные значения')
plt.ylabel('Ошибка предсказаний')
plt.title('Ошибка предсказаний vs Предсказанные значения (Обучающая выборка)')
plt.show()

# 4. Ошибка предсказаний vs Предсказанные значения (Валидационная выборка)
valid_residuals = y_valid - y_valid_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_valid_pred, valid_residuals, alpha=0.3, color='green')
plt.hlines(y=0, xmin=y_valid_pred.min(), xmax=y_valid_pred.max(), colors='r')
plt.xlabel('Предсказанные значения')
plt.ylabel('Ошибка предсказаний')
plt.title('Ошибка предсказаний vs Предсказанные значения (Валидационная выборка)')
plt.show()

# 5. Гистограмма распределения ошибки предсказаний (Обучающая выборка)
plt.figure(figsize=(10, 6))
sns.histplot(train_residuals, kde=True)
plt.xlabel('Ошибка предсказаний')
plt.title('Распределение ошибок предсказаний (Обучающая выборка)')
plt.show()

# 6. Гистограмма распределения остатков (Валидационная выборка)
plt.figure(figsize=(10, 6))
sns.histplot(valid_residuals, kde=True, color='purple')
plt.xlabel('Ошибки предсказаний')
plt.title('Распределение ошибок предсказаний (Валидационная выборка)')
plt.show()

# %% [markdown]
# ### 6. Получение результатов и загрузка

# %%
# загрузка датасета для заполнения ответами
df_answer = pd.read_csv('../sample_submission.csv')

# загрузка датасета для проведения предсказания
df_test = pd.read_csv('/Users/alex_eyfler/ds_bootcamp/first-phase-projects/house_prices_kaggle_regression/Lambert/Lam_test.csv')

# %%
# Предсказания на логарифмических данных
y_log_test_pred = cat_boost_2.predict(df_test)

# Возвращаемся к исходной шкале
y_test_pred = np.exp(y_log_test_pred)

# Записываем ответы
df_answer['SalePrice'] = y_test_pred

# Сохраняем ответы для отправки на Kaggle
df_answer.to_csv('../submission_lambert.csv', index=False)

# %% [markdown]
# ### 7. Сохранение модели

# %%
cat_boost_2.save_model('catboost_model_lam_data.cbm')
